# %% [markdown]
# Documentation
# *   the 'category2keyword' will be reviesed in each iteration.
# *   'script' method is the entry point of the code.
# *   'utils' section contains the utility funcitons
# *   *   Need to enter the input in runner section. There multiple cell contians the code to run for all dataset at once / to run for states saperately / to run for districts saperately
#     * Based on each run two files will be generated for each district '\<district>.csv' and 'blank_\<district>.csv'
#     * based on the blank_\<district>.csv the 'category2keywrod' rules will be revised on each run to maximize the number of categorized works.

# %% [markdown]
# ### Rules

# %%
category2keyword = {
    'Irrigation - Site level impact': ['bund', 'bandh', 'बांध', 'बांध', 'बॉध',
                                       'tank',
                                       'irrigation',
                                       'well-filter', 'koop-filter', 'कुऑ-filter', 'कूप-filter', 'कुप-filter', 'kup-filter',
                                       'तालाब-fish', 'pond-fish', 'dobha-fish', 'talab-fish', 'pokhar-fish', 'pokhra-fish', 'पोखर-fish',
                                       'percolation',
                                       'desilting',
                                       'sichai kup', 'sinchai kup', 'सिंचाई कूप',
                                       'fp of',
                                       'nali nirman', 'नाली निर्माण',
                                       ],
    'SWC - Landscape level impact': ['aahar', 'ahhar', 'ahar', 'अहार', 'अहर', 'आहार', 'आहर',
                                     'sarkari', 'government',
                                     'anicut', 'dam', 'चेकडेम',
                                     'terrace', 'trench', 'diversion channel', 'diversion drain', 'diversion',
                                     'drain-plantation', 'gabion', 'bench', 'plug', 'canal-plantation', 'नाली', 'नाला-plantation', 'pit-compost',
                                     'channel', 'embank', 'drain-drainage', 'dyke', 'watercourse', 'soak', 'spur'
                                     'whs', 'w.h.s.',
                                     'silviculture',
                                     'excavation',
                                     'sokhata nirman',
                                     'reclamation land', # 'reclamation of land',
                                     'loose bolder', 'loose boulder', # 'loose bolder structure'
                                     ],

    'Plantation': ['plantation', 'palantation', 'plantaion', 'वृक्षारोपण', 'वक्षारोपण', 'briksha', 'vriksharopan', 'brixaropan', 'brakharopn', 'वृक्षा',  'tree',
                   'forestry', 'nursery', 'forest', 'grass', 'farm forestri',
                   'afforestation', 'farm forestry', 'silvipasture', 'shelter belt', 'horticulture', 'sericulture'],

    'Household Livelihood': ['shelter', 'fishery pond', 'drying yard', 'cattle', 'goat',
                             'poultry', 'poltri',
                             'piggery', 'livestock', 'fish'],

    'Agri Impact - HH,  Community': ['land levelling', 'land leveling', 'land development',
                                     'chaur land', 'compost pit', 'fallow land',
                                     'shaping land', 'nadep', 'storage build', 'waterlogged land', 'waste land', 'storage building',
                                     'berkeley', 'vermi', 'azola', 'storage', 'biomanure',
                                     'nalla', 'nallah', 'nulla',
                                     'bpg', 'b.pg', 'bp.g', 'bpg.', 'b.p.g', 'b.pg.', 'bp.g.', 'b.p.g.',
                                     'pmay-g', 'pmayg',
                                     'मिटटी भराई', 'मिटी भराई',
                                     'miti bharai',
                                     'keth samtlikarn', 'samtali karan', 'समतलीकारण',
                                     'karaha katai',
                                     ],

    'Others - HH, Community': ['cement concrete',
                               'kharanja', 'karanja',
                               'haat', 'field', 'mitti',
                               'anganwadi', 'aganbari', 'anganbadi', 'आगंवारी', 'आगनबाडी', 'aaganwadi',
                               'crematorium',
                               'toilet', 'latrine', 'showchalay', 'sauchalay', 'souchliya', 'शौचालय',
                               'shed', 'sed nirman', 'wall', 'diwal',
                               'dibar', 'kitchen', 'bhavan', 'murrarn','मोरम', 'moram', 'house', 'bitumen', 'gravel',
                               'road', 'सडक', 'रोड', 'sadak',
                               'सड्क', 'school', 'vidyalay', 'vidyalya', 'विदयालय',
                               'awaas', 'awaas', 'आवास', 'आवस', 'अवास', 'अवस',
                               'sewa kendra', 'seva kendra', 'seba kendra', 'sheva kendra', 'seva kendra',
                               'iay', 'i.a.y.', 'i.ay', 'ia.y', 'iay.', 'i.a.y', 'ia.y.', 'i.ay.',
                               'fencing', 'fence',
                               'awc',
                               'play ground',
                               'ihhl',
                               'public assets',
                               'पुलिया निर्माण', 'पुल निर्माण',
                               'brick soling', 'pcc',
                               'ईट सोलिंग',
                                'कलभट', 'kalbhat', 'kalabhat',
                                'rcc puliya', 'rcc',
                                'cement lining',
                                'building material', # 'production of building material',
                               'minors', 'sub minors',
                               'makan nirman',
                               'safai', 'saphai'
                               'chabutara', 'chhawar'
                               ],

    'Irrigation Site level - Non RWH': ['filter', 'boring']
}

# %% [markdown]
# ### Utils

# %%
import pandas as pd
import re

def remove_special_chars(line):
  if isinstance(line, float): return ''
  if isinstance(line, int): return ''
  line = line.replace('?', ' ')
#   line = line.replace('.', '')
  line = line.replace(',', ' ')
  line = line.replace('&', ' ')
  # line = line.replace('-', ' ') # example: de-silted
  line = line.replace('%', ' ')
  line = line.replace('@', ' ')
  line = line.replace('(', ' ')
  line = line.replace(')', ' ')
  line = line.replace('/', ' ')
  line = line.replace('\\', ' ')
  line = line.replace('_', ' ')
  line = line.replace('[', ' ')
  line = line.replace(']', ' ')
  line = line.replace('{', ' ')
  line = line.replace('}', ' ')
  line = line.replace('$', ' ')
  line = line.replace('#', ' ')
  line = line.replace('!', ' ')
  line = line.replace('^', ' ')
  line = line.replace('*', ' ')
  line = line.replace('+', ' ')
  line = line.replace('=', ' ')
  line = line.replace('|', ' ')
  line = line.replace(';', ' ')
  line = line.replace('<', ' ')
  line = line.replace('>', ' ')
  line = line.replace(':', ' ')
  line = re.sub(r'\d', ' ', line)
  line = line.strip()
  return line

def remove_short_words(line):
  stop_words = [
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves",
    "you", "your", "yours", "yourself", "yourselves",
    "he", "him", "his", "himself", "she", "her", "hers", "herself",
    "it", "its", "itself", "they", "them", "their", "theirs", "themselves",
    "what", "which", "who", "whom", "this", "that", "these", "those",
    "am", "is", "are", "was", "were", "be", "been", "being",
    "have", "has", "had", "having", "do", "does", "did", "doing",
    "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
    "of", "at", "by", "for", "with", "about", "against", "between", "into", "through",
    "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out",
    "on", "off", "over", "under", "again", "further", "then", "once",
    "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few",
    "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same",
    "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now",

    "along", "continious", "for", "ior", "lor", "tor"
  ]
  words = line.split(' ')
  words = list(filter(lambda word : len(word)>2, words))
  words = list(filter(lambda word: word not in stop_words, words))
  line = ' '.join(words)
  return line

category2keyword = category2keyword

def clean(string):
    string = str(string)
    string = string.lower()
    string = remove_special_chars(string)
    string = remove_short_words(string)
    return string

def getKeywork2category(category2keyword):
    res = []
    for category, keywords in category2keyword.items():
        for keyword in keywords:
            if '-' in keyword: continue
            # res[keyword.strip()] = category
            res.append([keyword, category])

    for category, keywords in category2keyword.items():
        for keyword in keywords:
            if '-' not in keyword: continue
            # res[keyword.strip()] = category
            res.append([keyword, category])

    return res

def check3(row, keyword, category, col_name):
    keyword = keyword.strip()
    # # if row['Keyword Found | Work Category'] != '':
    # #     return row['Keyword Found | Work Category']
    # prev = row['Keyword Found | Work Category'].split(' || ')
    # if keyword in row[f'{col_name} Cleaned'].split(' '):
    #     prev.append(f"{keyword} | {category}")
    # else:
    #     prev
    # return ' || '.join(prev)

    if row['Keyword Found | Work Category'] != '':
        return row['Keyword Found | Work Category']
    if keyword in row[f'{col_name} Cleaned']:
        return f"{keyword} | {category}"
    else:
        return ''

def check2(row, keyword, category, col_name):
    keyword = keyword.strip()
    key1, key2 = keyword.split(' ')
    # # if row['Keyword Found | Work Category'] != '':
    # #     return row['Keyword Found | Work Category']
    # prev = row['Keyword Found | Work Category'].split(' || ')
    # if key1 in row[f'{col_name} Cleaned'] and key2 in row[f'{col_name} Cleaned']:
    #     prev.append(f"{keyword} | {category}")
    # else:
    #     prev
    # return ' || '.join(prev)

    if row['Keyword Found | Work Category'] != '':
        return row['Keyword Found | Work Category']
    if key1 in row[f'{col_name} Cleaned'] and key2 in row[f'{col_name} Cleaned']:
        return f"{keyword} | {category}"
    else:
        return ''

def check1(row, keyword, category, col_name):
    keyword = keyword.strip()
    key1, key2 = keyword.split('-')
    # # if row['Keyword Found | Work Category'] != '':
    # #     return row['Keyword Found | Work Category']
    # prev = row['Keyword Found | Work Category'].split(' || ')
    # if key1 in row[f'{col_name} Cleaned'] and key2 not in row[f'{col_name} Cleaned']:
    #     prev.append(f"{keyword} | {category}")
    # else:
    #     prev
    # return ' || '.join(prev)

    if row['Keyword Found | Work Category'] != '':
        return row['Keyword Found | Work Category']
    if key1 in row[f'{col_name} Cleaned'] and key2 not in row[f'{col_name} Cleaned']:
        return f"{keyword} | {category}"
    else:
        return ''

# keyword2category = getKeywork2category(category2keyword)
# print(keyword2category)

def apply_transformer(category2keyword, data):
    data['Work Name Cleaned']=data['Work Name'].apply(clean)
    data['Asset Name Cleaned']=data['Asset Name'].apply(clean)
    data['Work Type Cleaned']=data['Work Type'].apply(clean)
    # data['info'] = data['Work Name'] + ' ' + data['Asset Name'] + ' ' + data['Work Type']

    keyword2category = getKeywork2category(category2keyword)
    data['Keyword Found | Work Category'] = ''

    # for keyword, category in keyword2category.items():
    for col in ['Work Name', 'Asset Name', 'Work Type']:
        for keyword, category in keyword2category:
            if '-' in keyword:
                data['Keyword Found | Work Category'] = data.apply(check1, axis=1, keyword=keyword, category=category, col_name=col)
            elif ' ' in keyword:
                data['Keyword Found | Work Category'] = data.apply(check2, axis=1, keyword=keyword, category=category, col_name=col)
            else:
                data['Keyword Found | Work Category'] = data.apply(check3, axis=1, keyword=keyword, category=category, col_name=col)


    data['Attention'] = data['Keyword Found | Work Category'].apply(lambda string : string.split(' | ')[0] if len(string.split(' | '))>1 else '')
    data['Work Category'] = data['Keyword Found | Work Category'].apply(lambda string : string.split(' | ')[1] if len(string.split(' | '))>1 else '')

    return data

def script(ip_file_path, op_file_path, op_file_path_for_blank_res):
    data = pd.read_csv(ip_file_path)
    result_df = apply_transformer(category2keyword, data)
    result_df.drop('Attention', inplace=True, axis=1)
    result_df.drop('Keyword Found | Work Category', inplace=True, axis=1)
    result_df.drop('Work Name Cleaned', inplace=True, axis=1)
    result_df.drop('Asset Name Cleaned', inplace=True, axis=1)
    result_df.drop('Work Type Cleaned', inplace=True, axis=1)
    result_df.to_csv(op_file_path, index=False)
    blank = result_df[(result_df['Work Category'].isna()) | (result_df['Work Category']=="")][['Asset Name', 'Work Name', 'Work Type']]
    blank.to_csv(op_file_path_for_blank_res, index=False)
    print(f'done')

# %% [markdown]
# ### Runner of the scripts

# %% [markdown]
# #### Find the state and its districts

# %%
import os
from pprint import pprint
path = '/content/drive/MyDrive/ICTD_Datasets/NREGA data/NREGA geotagged assets metadata [csv]/'
states = os.listdir(path)

state_districts = {}
for state in states:
    # print(f'State: {state}')
    districts = []
    for district in os.listdir(os.path.join(path, state)):
        # print(f'District: {district}')
        if district.endswith('csv'): districts.append(district)
    state_districts[state] = districts


pprint(state_districts)
# Out:
# {'ANDAMAN AND NICOBAR': [],
#  'ANDHRA PRADESH': ['KRISHNA.csv',
#                     'WEST GODAVARI.csv',
#                     'VIZIANAGARAM.csv',
#                     'CHITTOOR.csv',
#                     'NELLORE.csv',
#                     'GUNTUR.csv',
#                     'VISAKHAPATANAM.csv',
#                     'SRIKAKULAM.csv',
#                     'CUDDAPAH.csv',
#                     'PRAKASAM.csv',
#                     'EAST GODAVARI.csv',
#                     'KURNOOL.csv',
#                     'ANANTAPUR.csv'],
#  'ARUNACHAL PRADESH': ['LOWER SUBANSIRI.csv',
#                        'PAPUM PARE.csv',
#                        'EAST SIANG.csv',
#                        'LOWER DIBANG VALLEY.csv',
#                        'WEST SIANG.csv',
#                        'ANJAW.csv',
#                        'TIRAP.csv',
#                        'UPPER SUBANSIRI.csv',
#                        'TAWANG.csv',
#                        'LOHIT.csv',
#                        'SIANG.csv',
#                        'UPPER SIANG.csv',
#                        'EAST KAMENG.csv',
#                        'UPPER DIBANG VALLEY.csv',
#                        'LONGDING.csv',
#                        'WEST KAMENG.csv',
#                        'CHANGLANG.csv',
#                        'KURUNG KUMEY.csv'],
#  'ASSAM': ['KAMRUP.csv',
#            'LAKHIMPUR.csv',
#            'DARRANG.csv',
#            'Dima Hasao.csv',
#            'SIVASAGAR.csv',
#            'HAILAKANDI.csv',
#            'CHIRANG.csv',
#            'GOLAGHAT.csv',
#            'BONGAIGAON.csv',
#            'UDALGURI.csv',
#            'KAMRUP (METRO).csv',
#            'GOALPARA.csv',
#            'SONITPUR.csv',
#            'BARPETA.csv',
#            'JORHAT.csv',
#            'KOKRAJHAR.csv',
#            'DHUBRI.csv',
#            'KARBI ANGLONG.csv',
#            'DIBRUGARH.csv',
#            'Morigaon.csv',
#            'TINSUKIA.csv',
#            'NAGAON.csv',
#            'KARIMGANJ.csv',
#            'CACHAR.csv',
#            'BAKSA.csv',
#            'NALBARI.csv',
#            'DHEMAJI.csv'],
#  'BIHAR': ['ARARIA.csv',
#            'ARWAL.csv',
#            'AURANAGABAD.csv',
#            'BEGUSARAI.csv',
#            'BHAGALPUR.csv',
#            'BHOJPUR.csv',
#            'DARBHANGA.csv',
#            'GAYA.csv',
#            'GOPALGANJ.csv',
#            'JAMUI.csv',
#            'JEHANABAD.csv',
#            'KAIMUR (BHABUA).csv',
#            'KATIHAR.csv',
#            'KHAGARIA.csv',
#            'KISHANGANJ.csv',
#            'LAKHISARAI.csv',
#            'MADHEPURA.csv',
#            'MADHUBANI.csv',
#            'MUNGER.csv',
#            'MUZAFFARPUR.csv',
#            'NALANDA.csv',
#            'NAWADA.csv',
#            'PASHCHIM CHAMPARAN.csv',
#            'PATNA.csv',
#            'PURBI CHAMPARAN.csv',
#            'PURNIA.csv',
#            'ROHTAS.csv',
#            'SAHARSA.csv',
#            'SAMASTIPUR.csv',
#            'SARAN.csv',
#            'SHEOHAR.csv',
#            'SITAMARHI.csv',
#            'SIWAN.csv',
#            'SUPAUL.csv',
#            'VAISHALI.csv',
#            'SHEIKHPURA.csv',
#            'BANKA.csv',
#            'BUXAR.csv'],
#  'CHHATTISGARH': ['BALODA BAZAR.csv',
#                   'BEMETARA.csv',
#                   'SURGUJA.csv',
#                   'SURAJPUR.csv',
#                   'KORBA.csv',
#                   'BALRAMPUR.csv',
#                   'RAIGARH.csv',
#                   'GARIYABAND.csv',
#                   'MAHASAMUND.csv',
#                   'DANTEWADA.csv',
#                   'RAJNANDAGON.csv',
#                   'BASTAR.csv',
#                   'DHAMTARI.csv',
#                   'BALOD.csv',
#                   'NARAYANPUR.csv',
#                   'BILASPUR.csv',
#                   'JASHPUR.csv',
#                   'JANJGIR-CHAMPA.csv',
#                   'KANKER.csv',
#                   'SUKMA.csv',
#                   'DURG.csv',
#                   'KONDAGAON.csv',
#                   'KAWARDHA.csv',
#                   'MUNGELI.csv',
#                   'BIJAPUR.csv',
#                   'RAIPUR.csv',
#                   'KOREA.csv'],
#  'DN HAVELI AND DD': [],
#  'GOA': ['SOUTH GOA.csv', 'NORTH GOA.csv'],
#  'GUJARAT': ['AMRELI.csv',
#              'DOHAD.csv',
#              'GANDHINAGAR.csv',
#              'KACHCHH.csv',
#              'KHEDA.csv',
#              'MAHISAGAR.csv',
#              'PANCH MAHALS.csv',
#              'SABAR KANTHA.csv',
#              'SURAT.csv',
#              'SURENDRANAGAR.csv',
#              'VADODARA.csv',
#              'DANG.csv',
#              'RAJKOT.csv',
#              'Morbi.csv',
#              'BANAS KANTHA.csv',
#              'AHMADABAD.csv',
#              'DEVBHUMI DWARKA.csv',
#              'PORBANDAR.csv',
#              'TAPI.csv',
#              'NAVSARI  .csv',
#              'BHARUCH.csv',
#              'GIR SOMNATH.csv',
#              'Chhotaudepur.csv',
#              'PATAN.csv',
#              'NARMADA.csv',
#              'JAMNAGAR.csv',
#              'BHAVNAGAR.csv',
#              'ANAND.csv',
#              'JUNAGADH.csv',
#              'ARVALLI.csv',
#              'MAHESANA.csv',
#              'VALSAD.csv'],
#  'HARYANA': ['FARIDABAD.csv',
#              'JHAJJAR.csv',
#              'BHIWANI.csv',
#              'YAMUNANAGAR.csv',
#              'PALWAL.csv',
#              'JIND.csv',
#              'KURUKSHETRA.csv',
#              'GURUGRAM.csv',
#              'FATEHABAD.csv',
#              'MEWAT.csv',
#              'KARNAL.csv',
#              'MAHENDRAGARH.csv',
#              'KAITHAL.csv',
#              'PANCHKULA.csv',
#              'PANIPAT.csv',
#              'SONIPAT.csv',
#              'REWARI.csv',
#              'ROHTAK.csv',
#              'AMBALA.csv',
#              'HISAR.csv',
#              'SIRSA.csv'],
#  'HIMACHAL PRADESH': ['CHAMBA.csv',
#                       'SOLAN.csv',
#                       'UNA.csv',
#                       'KINNAUR.csv',
#                       'MANDI.csv',
#                       'KANGRA.csv',
#                       'BILASPUR.csv',
#                       'LAHUL AND SPITI.csv',
#                       'SHIMLA.csv',
#                       'KULLU.csv',
#                       'HAMIRPUR.csv'],
#  'JAMMU AND KASHMIR': ['ANANTNAG.csv',
#                        'BANDIPORA.csv',
#                        'BARAMULLA.csv',
#                        'DODA.csv',
#                        'GANDERBAL.csv',
#                        'KATHUA.csv',
#                        'KISHTWAR.csv',
#                        'KULGAM.csv',
#                        'POONCH.csv',
#                        'RAMBAN.csv',
#                        'SAMBA.csv',
#                        'REASI.csv',
#                        'SHOPIAN.csv',
#                        'SRINAGAR.csv',
#                        'JAMMU.csv',
#                        'BADGAM.csv',
#                        'KUPWARA.csv',
#                        'RAJAURI.csv',
#                        'UDHAMPUR.csv',
#                        'PULWAMA.csv'],
#  'JHARKHAND': ['DEOGHAR.csv',
#                'PAKUR.csv',
#                'RAMGARH.csv',
#                'KODERMA.csv',
#                'CHATRA.csv',
#                'LATEHAR.csv',
#                'GODDA.csv',
#                'LOHARDAGA.csv',
#                'SIMDEGA.csv',
#                'WEST SINGHBHUM.csv',
#                'EAST SINGHBUM.csv',
#                'KHUNTI.csv',
#                'DHANBAD.csv',
#                'SARAIKELA KHARSAWAN.csv',
#                'GIRIDIH.csv',
#                'SAHEBGANJ.csv',
#                'PALAMU.csv',
#                'GARHWA.csv',
#                'JAMTARA.csv',
#                'BOKARO.csv',
#                'RANCHI.csv',
#                'HAZARIBAGH.csv',
#                'DUMKA.csv',
#                'GUMLA.csv'],
#  'KARNATAKA': ['CHIKKABALLAPURA.csv',
#                'KALABURAGI.csv',
#                'KODAGU.csv',
#                'SHIVAMOGGA.csv',
#                'BELAGAVI.csv',
#                'DAKSHINA KANNADA.csv',
#                'BENGALURU RURAL.csv',
#                'KOLAR.csv',
#                'BENGALURU.csv',
#                'UDUPI.csv',
#                'TUMAKURU.csv',
#                'DAVANAGERE.csv',
#                'CHITRADURGA.csv',
#                'CHIKKAMAGALURU.csv',
#                'GADAG.csv',
#                'HAVERI.csv',
#                'Yadgir.csv',
#                'CHAMARAJA NAGARA.csv',
#                'BALLARI.csv',
#                'RAICHUR.csv',
#                'MYSURU.csv',
#                'BAGALKOTE.csv',
#                'KOPPAL.csv',
#                'HASSAN.csv',
#                'DHARWAR.csv',
#                'BIDAR.csv',
#                'UTTARA KANNADA.csv',
#                'VIJAYPURA.csv',
#                'MANDYA.csv'],
#  'KERALA': ['KOZHIKODE.csv',
#             'KANNUR.csv',
#             'MALAPPURAM.csv',
#             'ERNAKULAM.csv',
#             'PATHANAMTHITTA.csv',
#             'ALAPPUZHA.csv',
#             'PALAKKAD.csv',
#             'THIRUVANANTHAPURAM.csv',
#             'THRISSUR.csv',
#             'IDUKKI.csv',
#             'KOLLAM.csv',
#             'KOTTAYAM.csv',
#             'WAYANAD.csv',
#             'KASARGOD.csv'],
#  'LADAKH': ['KARGIL.csv', 'LEH (LADAKH).csv'],
#  'LAKSHADWEEP': [],
#  'MADHYA PRADESH': ['SEONI.csv',
#                     'GUNA.csv',
#                     'HOSHANGABAD.csv',
#                     'DEWAS.csv',
#                     'DATIA.csv',
#                     'DINDORI.csv',
#                     'MANDSAUR.csv',
#                     'BHOPAL.csv',
#                     'BHIND.csv',
#                     'RATLAM.csv',
#                     'DHAR.csv',
#                     'MORENA.csv',
#                     'JABALPUR.csv',
#                     'GWALIOR.csv',
#                     'DAMOH.csv',
#                     'INDORE.csv',
#                     'SATNA.csv',
#                     'CHHATARPUR.csv',
#                     'SEHORE.csv',
#                     'HARDA .csv',
#                     'CHHINDWARA.csv',
#                     'BARWANI.csv',
#                     'ASHOK NAGAR.csv',
#                     'KHARGONE.csv',
#                     'MANDLA.csv',
#                     'BURHANPUR.csv',
#                     'KHANDWA.csv',
#                     'KATNI .csv',
#                     'BETUL.csv',
#                     'BALAGHAT.csv'],
#  'MAHARASHTRA': ['KOLHAPUR.csv',
#                  'GADCHIROLI.csv',
#                  'BEED.csv',
#                  'NASHIK.csv',
#                  'NANDURBAR.csv',
#                  'AKOLA.csv',
#                  'LATUR.csv',
#                  'OSMANABAD.csv',
#                  'CHANDRAPUR.csv',
#                  'SANGLI.csv',
#                  'HINGOLI.csv',
#                  'RAIGAD.csv',
#                  'PARBHANI.csv',
#                  'AHMEDNAGAR.csv',
#                  'JALGAON.csv',
#                  'BHANDARA.csv',
#                  'AURANGABAD.csv',
#                  'AMRAVATI.csv',
#                  'NANDED.csv',
#                  'BULDHANA.csv',
#                  'GONDIA.csv',
#                  'DHULE.csv',
#                  'JALNA.csv',
#                  'PUNE.csv',
#                  'NAGPUR.csv',
#                  'RATNAGIRI.csv'],
#  'MANIPUR': ['THOUBAL.csv',
#              'UKHRUL.csv',
#              'BISHNUPUR.csv',
#              'SENAPATI.csv',
#              'CHURACHANDPUR.csv',
#              'IMPHAL WEST.csv',
#              'TAMENGLONG.csv',
#              'CHANDEL.csv',
#              'IMPHAL EAST.csv'],
#  'MEGHALAYA': ['WEST GARO HILLS (2).csv',
#                'WEST GARO HILLS.csv',
#                'EAST GARO HILLS (2).csv',
#                'NORTH GARO HILLS (2).csv',
#                'EAST GARO HILLS.csv',
#                'NORTH GARO HILLS.csv',
#                'RI BHOI   (2).csv',
#                'RI BHOI  .csv',
#                'EAST KHASI HILLS (2).csv',
#                'EAST KHASI HILLS.csv',
#                'WEST KHASI HILLS (2).csv',
#                'WEST KHASI HILLS.csv',
#                'SOUTH WEST GARO HILLS (2).csv',
#                'SOUTH WEST GARO HILLS.csv',
#                'East Jaintia Hills (2).csv',
#                'WEST JAINTIA HILLS (2).csv',
#                'East Jaintia Hills.csv',
#                'SOUTH WEST KHASI HILLS (2).csv',
#                'WEST JAINTIA HILLS.csv',
#                'SOUTH WEST KHASI HILLS.csv',
#                'SOUTH GARO HILLS (2).csv',
#                'SOUTH GARO HILLS.csv',
#                'EAST GARO HILLS (1).csv',
#                'East Jaintia Hills (1).csv',
#                'EAST KHASI HILLS (1).csv',
#                'NORTH GARO HILLS (1).csv',
#                'RI BHOI   (1).csv',
#                'SOUTH GARO HILLS (1).csv',
#                'SOUTH WEST GARO HILLS (1).csv',
#                'SOUTH WEST KHASI HILLS (1).csv',
#                'WEST JAINTIA HILLS (1).csv',
#                'WEST GARO HILLS (1).csv',
#                'WEST KHASI HILLS (1).csv'],
#  'MIZORAM': ['AIZAWL.csv',
#              'CHAMPHAI .csv',
#              'KOLASIB.csv',
#              'LAWNGTLAI.csv',
#              'LUNGLEI.csv',
#              'MAMIT.csv',
#              'SERCHHIP.csv',
#              'SAIHA.csv'],
#  'NAGALAND': ['DIMAPUR.csv',
#               'KIPHIRE.csv',
#               'LONGLENG.csv',
#               'MOKOKCHUNG.csv',
#               'KOHIMA.csv',
#               'PEREN.csv',
#               'MON.csv',
#               'TUENSANG.csv',
#               'PHEK.csv',
#               'ZUNHEBOTO.csv',
#               'WOKHA.csv'],
#  'ODISHA': ['ANGUL.csv',
#             'BALESHWAR.csv',
#             'BARGARH.csv',
#             'BHADRAK.csv',
#             'BOLANGIR.csv',
#             'BOUDH.csv',
#             'CUTTACK.csv',
#             'DEOGARH.csv',
#             'DHENKANAL.csv',
#             'GAJAPATI.csv',
#             'GANJAM.csv',
#             'JAGATSINGHAPUR.csv',
#             'JAJPUR.csv',
#             'JHARSUGUDA.csv',
#             'KALAHANDI.csv',
#             'KANDHAMAL.csv',
#             'KENDRAPARA.csv',
#             'KENDUJHAR.csv',
#             'KHORDHA.csv',
#             'KORAPUT.csv',
#             'MALKANGIRI.csv',
#             'MAYURBHANJ.csv',
#             'NABARANGAPUR.csv',
#             'NAYAGARH.csv',
#             'NUAPADA.csv',
#             'PURI.csv',
#             'RAYAGADA.csv',
#             'SAMBALPUR.csv',
#             'SONEPUR.csv',
#             'SUNDARGARH.csv'],
#  'PUDUCHERRY': ['KARAIKAL.csv', 'PONDICHERRY.csv'],
#  'PUNJAB': ['BARNALA.csv',
#             'AMRITSAR.csv',
#             'FARIDKOT.csv',
#             'BHATINDA                  .csv',
#             'Fazilka.csv',
#             'FATEHGARH SAHIB.csv',
#             'FEROZEPUR                 .csv',
#             'GURDASPUR.csv',
#             'JALANDHAR.csv',
#             'HOSHIARPUR.csv',
#             'KAPURTHALA.csv',
#             'LUDHIANA.csv',
#             'MANSA.csv',
#             'MOGA.csv',
#             'NAWANSHAHR .csv',
#             'MUKATSAR.csv',
#             'Pathankot.csv',
#             'SANGRUR.csv',
#             'PATIALA.csv',
#             'ROPAR.csv',
#             'SAS NAGAR MOHALI.csv',
#             'TARN TARAN.csv'],
#  'RAJASTHAN': ['AJMER.csv',
#                'ALWAR.csv',
#                'BANSWARA.csv',
#                'BARAN.csv',
#                'BARMER.csv',
#                'BHARATPUR.csv',
#                'BHILWARA.csv',
#                'BIKANER.csv',
#                'BUNDI.csv',
#                'CHITTORGARH.csv',
#                'CHURU.csv',
#                'DAUSA.csv',
#                'DHOLPUR.csv',
#                'DUNGARPUR.csv',
#                'HANUMANGARH.csv',
#                'JAIPUR.csv',
#                'JAISALMER.csv',
#                'JALORE.csv',
#                'JHALAWAR.csv',
#                'JHUNJHUNU.csv',
#                'JODHPUR.csv',
#                'KARAULI.csv',
#                'KOTA.csv',
#                'NAGAUR.csv',
#                'PALI.csv',
#                'PRATAPGARH.csv',
#                'RAJSAMAND.csv',
#                'SAWAI MADHOPUR.csv',
#                'SIKAR.csv',
#                'SIROHI.csv',
#                'SRI GANGANAGAR.csv',
#                'TONK.csv',
#                'UDAIPUR.csv'],
#  'SIKKIM': ['EAST DISTRICT.csv',
#             'NORTH DISTRICT.csv',
#             'SOUTH DISTRICT.csv',
#             'WEST DISTRICT.csv'],
#  'TAMIL NADU': ['ARIYALUR.csv',
#                 'COIMBATORE.csv',
#                 'CUDDALORE.csv',
#                 'DHARMAPURI.csv',
#                 'DINDIGUL.csv',
#                 'ERODE.csv',
#                 'KANCHIPURAM.csv',
#                 'KANNIYAKUMARI.csv',
#                 'KARUR.csv',
#                 'KRISHNAGIRI.csv',
#                 'MADURAI.csv',
#                 'NAGAPATTINAM.csv',
#                 'NAMAKKAL.csv',
#                 'PERAMBALUR.csv',
#                 'PUDUKKOTTAI.csv',
#                 'RAMANATHAPURAM.csv',
#                 'SALEM.csv',
#                 'SIVAGANGAI.csv',
#                 'THANJAVUR.csv',
#                 'THE NILGIRIS.csv',
#                 'THENI.csv',
#                 'THOOTHUKKUDI.csv',
#                 'TIRUCHIRAPPALLI.csv',
#                 'TIRUNELVELI.csv',
#                 'TIRUPPUR.csv',
#                 'TIRUVALLUR.csv',
#                 'TIRUVANNAMALAI.csv',
#                 'TIRUVARUR.csv',
#                 'VELLORE.csv',
#                 'VILLUPURAM.csv',
#                 'VIRUDHUNAGAR.csv'],
#  'TELANGANA': ['KARIMNAGAR.csv',
#                'KHAMMAM.csv',
#                'NIZAMABAD.csv',
#                'WARANGAL.csv',
#                'MAHBUBNAGAR.csv',
#                'ADILABAD.csv'],
#  'TRIPURA': ['DHALAI.csv',
#              'Gomati.csv',
#              'Khowai.csv',
#              'NORTH TRIPURA.csv',
#              'Sepahijala.csv',
#              'SOUTH TRIPURA.csv',
#              'Unakoti.csv',
#              'WEST TRIPURA.csv'],
#  'UTTAR PRADESH': ['AMETHI.csv',
#                    'BULANDSHAHR.csv',
#                    'BAHRAICH.csv',
#                    'AMROHA.csv',
#                    'AGRA.csv',
#                    'BIJNOR.csv',
#                    'BALRAMPUR.csv',
#                    'GONDA.csv',
#                    'AMBEDKAR NAGAR.csv',
#                    'HAPUR.csv',
#                    'GORAKHPUR.csv',
#                    'DEORIA.csv',
#                    'AURAIYA.csv',
#                    'BAGHPAT.csv',
#                    'GAUTAM BUDDHA NAGAR.csv',
#                    'CHITRAKOOT.csv',
#                    'FIROZABAD.csv',
#                    'HATHRAS.csv',
#                    'BALLIA.csv',
#                    'BAREILLY.csv',
#                    'FATEHPUR.csv',
#                    'BARABANKI.csv',
#                    'GHAZIPUR.csv',
#                    'CHANDAULI.csv',
#                    'BANDA.csv',
#                    'FARRUKHABAD.csv',
#                    'ALIGARH.csv',
#                    'GHAZIABAD.csv',
#                    'AYODHYA.csv',
#                    'HARDOI.csv',
#                    'ETAH.csv',
#                    'BASTI.csv',
#                    'AZAMGARH.csv',
#                    'HAMIRPUR.csv',
#                    'ETAWAH.csv',
#                    'BUDAUN.csv',
#                    'MAHARAJGANJ.csv',
#                    'SHRAVASTI.csv',
#                    'KUSHI NAGAR.csv',
#                    'SANT KABEER NAGAR.csv',
#                    'SIDDHARTH NAGAR.csv'],
#  'WEST BENGAL': []}

# %% [markdown]
# #### Run the script for each of the districts

# %% [markdown]
# ##### Multithreaded execution

# %%
import threading

version = '1'

OUTPUT_DIR = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

state_count = 3
for state in states:
    state_count -= 1
    if state_count < 0: break

    threads = []
    if not os.path.exists(os.path.join(OUTPUT_DIR, state)):
        os.makedirs(os.path.join(OUTPUT_DIR, state))
    district_count = 3
    for district in state_districts[state]:
        district = district.split('.')[0]
        district_count -= 1
        if district_count < 0: break

        ip_file_path = f'/content/drive/MyDrive/ICTD_Datasets/NREGA data/NREGA geotagged assets metadata [csv]/{state}/{district}.csv'
        op_file_path = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/{district}.csv'
        op_file_path_for_blank_res = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/blank_{district}.csv'


        print(f'{state = :.<20}{district = }')
        # try:
        if True:
            thread = threading.Thread(target=script, args=(ip_file_path, op_file_path, op_file_path_for_blank_res))
            threads.append(thread)
            thread.start()
        # except Exception as e:
        #     print(f"ERROR : {e}")
    for t in threads:
        t.join()

# %% [markdown]
# ##### Single threaded execution

# %%
version = '1'

OUTPUT_DIR = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)


for state in states:
    if not os.path.exists(os.path.join(OUTPUT_DIR, state)):
        os.makedirs(os.path.join(OUTPUT_DIR, state))
    for district in state_districts[state]:
        district = district.split('.')[0]
        ip_file_path = f'/content/drive/MyDrive/ICTD_Datasets/NREGA data/NREGA geotagged assets metadata [csv]/{state}/{district}.csv'
        op_file_path = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/{district}.csv'
        op_file_path_for_blank_res = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/blank_{district}.csv'

        print(f'{state = :.<20}{district = }')
        script(ip_file_path, op_file_path, op_file_path_for_blank_res)

# %% [markdown]
# ##### single district execution

# %%
version = '1'
state = 'RAJASTHAN' # 'RAJASTHAN' #
district = 'BHILWARA' # 'SIROHI' #

# 'RAJASTHAN', 'SIROHI', 'PINDWARA'
# 'JHARKHAND', 'DUMKA', 'MASALIA'
# 'BIHAR', 'GAYA', 'MOHANPUR'
# 'RAJASTHAN', 'BHILWARA', 'MANDALGRAH'
# 'ODISHA', 'ANGUL', 'ANGUL'


OUTPUT_DIR = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)


if not os.path.exists(os.path.join(OUTPUT_DIR, state)):
    os.makedirs(os.path.join(OUTPUT_DIR, state))

district = district.split('.')[0]
ip_file_path = f'/content/drive/MyDrive/ICTD_Datasets/NREGA data/NREGA geotagged assets metadata [csv]/{state}/{district}.csv'
op_file_path = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/{district}.csv'
op_file_path_for_blank_res = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/blank_{district}.csv'

print(f'{state = :.<20}{district = }')
script(ip_file_path, op_file_path, op_file_path_for_blank_res)
# Out:
# state = RAJASTHAN...........district = 'BHILWARA'
# done

# %% [markdown]
# ##### Single state execution

# %%
import os
version = '1'

OUTPUT_DIR = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)


state = 'ODISHA'
if not os.path.exists(os.path.join(OUTPUT_DIR, state)):
    os.makedirs(os.path.join(OUTPUT_DIR, state))
for district in state_districts[state]:
    district = district.split('.')[0]
    ip_file_path = f'/content/drive/MyDrive/ICTD_Datasets/NREGA data/NREGA geotagged assets metadata [csv]/{state}/{district}.csv'
    op_file_path = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/{district}.csv'
    op_file_path_for_blank_res = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/blank_{district}.csv'

    print(f'{state = :.<20}{district = }')
    script(ip_file_path, op_file_path, op_file_path_for_blank_res)
# Out:
# state = ODISHA..............district = 'ANGUL'
# done
# state = ODISHA..............district = 'BALESHWAR'
# done
# state = ODISHA..............district = 'BARGARH'
# done
# state = ODISHA..............district = 'BHADRAK'
# done
# state = ODISHA..............district = 'BOLANGIR'
# done
# state = ODISHA..............district = 'BOUDH'
# done
# state = ODISHA..............district = 'CUTTACK'
# done
# state = ODISHA..............district = 'DEOGARH'
# done
# state = ODISHA..............district = 'DHENKANAL'
# done
# state = ODISHA..............district = 'GAJAPATI'
# done
# state = ODISHA..............district = 'GANJAM'
# done
# state = ODISHA..............district = 'JAGATSINGHAPUR'
# done
# state = ODISHA..............district = 'JAJPUR'
# done
# state = ODISHA..............district = 'JHARSUGUDA'
# done
# state = ODISHA..............district = 'KALAHANDI'
# done
# state = ODISHA..............district = 'KANDHAMAL'

# %% [markdown]
# ### Checking the uncatorized rows to expand the dictionary of rules

# %%
version = '1'
state = 'RAJASTHAN' # 'RAJASTHAN' #
district = 'BHILWARA' # 'SIROHI' #

# 'RAJASTHAN', 'SIROHI', 'PINDWARA'
# 'JHARKHAND', 'DUMKA', 'MASALIA'
# 'BIHAR', 'GAYA', 'MOHANPUR'
# 'RAJASTHAN', 'BHILWARA', 'MANDALGRAH'
# 'ODISHA', 'ANGUL', 'ANGUL'

file_path = f'/content/drive/MyDrive/rittwick_tirumal/NREGA Assets/outputv{version}/{state}/{district}.csv'

# %%
data=pd.read_csv(file_path)

# %%
blank_data = data[data['Work Category'].isna()][['Asset Name', 'Work Name', 'Work Type']]
asset_names = list(set(blank_data['Asset Name'].tolist()))
work_names = list(set(blank_data['Work Name'].tolist()))
work_types = list(set(blank_data['Work Type'].tolist()))

# %%
asset_names
# Out:
# ['जालरीया छाटियो के एनिकट पर फेसवाल व मिटटी कार्य',
#  'mjs sarvjnik dharm talai sagas g',
#  'रामजी की नाडी की अधुरी फेसवाल को पूर्ण करना',
#  'tytytytytytytyty',
#  'AV/112908194934 ~~~~ आंगनवाडी केन्\u200dद्र भवन निर्माण कार्य मारवों का खेडा',
#  'regro k shamshan',
#  'Mitty Kary',
#  'श्रीनगर जस्\u200dसाजी का खेडा एमजेएसए त़तिय फेज के तहत भैरू जी की नाडी मरम्\u200dमत कार्य',
#  'बिगोद पीपली वाली नाडी गहरी कराना व आव निर्माण कार्य मालीखेडा',
#  'एमजेएस दितीय फेज के तहत आवरीमाता मन्दिर के पास एनिकट का गहरीकरण कार्य',
#  'काला भाटा डोलि के पास जलसंरक्षण ढांचा निर्माण जालरिया',
#  'मोटरो का खेडा शमसान घाट से नहर तक खाल गहरा करना नसिंह सागर',
#  '6',
#  'CC Block & Naali Nirman',
#  'wh/116579',
#  'Nai Naadi',
#  '7649',
#  'सेमला का बाडिया में पुरानी टुटी नाडी पर मिटी कार्य करवाना',
#  'एमजेएसए - द्वितीय फेज के तहत थला तलाई का एनिकट का गहरीकरण कार्य',
#  'maredi nadi',
#  'Renovation of Nadi',
#  'NATHOLAI DEVNARAYAN ANICAT FESWAL',
#  '112908173154',
#  'TEJAJI KI NADI FESWAL GHAT AAV',
#  'rasta',
#  '2701072035',
#  'Ramdev sagar',
#  'kagso ka kheda  jagrup gurjar ke nohre se gopi gurjar',
#  'indrapura nadi',
#  'CHARGA NADI GAHRI OR PINCHING',
#  'खाद्य सुरक्षा गोदाम निर्माण कार्य-बडला',
#  'काला पायरा चारागाह में नाडी गहरी करना फेसवाल व पक्\u200dका कार्य',
#  'hanumanji se mataji',
#  'NADI NIRMAN GP KANWLAS',
#  '2724011215/FG/112908175920',
#  '1',
#  'WH/112908134446',
#  'food grian',
#  'Water Conversation',
#  '112908145723',
#  'dsfsdfdgdgdg',
#  'Drought Proofing',
#  'dariba se kotri',
#  'नाडी निर्माण',
#  'मान सरिया के पास खाती की नाडी गहरी करना व फेसवाल कार्य -परा',
#  'नाडी निर्माण कार्य रेवाडा',
#  'Nadi Gahri Sangrampura',
#  'gWAL gADI',
#  'vidhayal se madan bairwa ke makan tak cc balok',
#  'चतरसिह जी की कटर मशीन तक ग्रेवल निर्माण (2724010123/RC/11007)',
#  'कमुनिया नाडी गहरी करना एंव पक्\u200dका कार्य',
#  'tagdiya nednadi nirman work',
#  'मकरेडी नाडी विस्\u200dतार व पानी आवक कार्य चारागाह हेमनिवास',
#  'साईमाता एनीकट मरम्मत व फेसवाल कार्य',
#  'Nade nirman',
#  'देवली नाडी को गहरा करना व फेसवाल मिटटी कार्य पालडी',
#  'एम0जे0एस0ए0 द्वतिय फेज के तहत बाहले पर एनिकट गहरीकरण कार्य',
#  'dev narayan nadi kagso ka kheda',
#  'Renovation Anikat',
#  'अहिरो का खेडा जल संरक्षण ढाचा र्निमाण अधुरी की पूर्ण करवाना फेसवाल व मिटटी कार्य',
#  'नाडी गहरी कराना सर का खेडा के पास महुवा',
#  'fjhffjhggkjghjk',
#  'mjsa balaji',
#  'ket sudhar work',
#  'wh/49886',
#  'मीणा मंगरी फेसवाल अधुरे कार्य को पूर्ण करना व मिटटी कार्य',
#  'आगनबाडी केन्द्र भवन निमाॅण हमीरगढ़',
#  'Shamshan  ke pass Nadi',
#  'Feshval niman ',
#  '2724002088/FG/112908175539',
#  'podha Ropan',
#  '2724011224/FG/2701073663',
#  'Renovation of Water Bodies ',
#  'एमजेएसए-दितिय फेज के तहत सामुदायिक नाडी नवीनीकरण कार्य',
#  'gopal/ panna',
#  '2724011245/FG/112908145743',
#  'AV/112908194896',
#  'kotri se gadri samaj',
#  'wh/12305',
#  '112908144370',
#  'रतनतलाई गहरी करण फेसवाल पाल ग्रेवल व पोधारोपण कार्य',
#  'रलायता दितिय फेज के तहत एनिकट मरम्\u200dमत कार्य भैरू जी धाकड के खेत के पास हिन्\u200dदू सिंह जी का खेडा',
#  'tretrettrrrtrytyt',
#  'खाद्य सुरक्षा गोदान निर्माण कार्य-कोटडी',
#  'FESWAAL',
#  'सरथला श्\u200dयालसचरा नाडी गहरी कराना व सुध्\u200dदडीकरण करना हरजेसपुरा',
#  'नाडी निर्माण कार्य',
#  'cc balok dhanna regar se upp. pri. sch. tak',
#  'FG/112908145907',
#  '271110072011',
#  '112908153361',
#  'सराणा खाघान्\u200dन भण्\u200dडारण गोदाम निर्माण कार्य सराणा',
#  'adsadadfadad',
#  'FG/112908175541',
#  'wH',
#  'nadi',
#  'Ghaylo ka khera',
#  '\tभील काॅलोनी में खुर्रा इन्\u200dटरलाॅक निर्माण',
#  'hfjhfjhfjhfjhhj',
#  'Govt bulliding plants',
#  'FG',
#  '2701072509',
#  'rrtrtrtrtrtretretret',
#  'Nadi nirman',
#  '2724002073/AV/112908146354',
#  'fdsfdsfdsfdsfdsafsad',
#  'MEERA KI BAHALI ANICAT FESWAL RAPAT',
#  'Food grain',
#  'water harvesting',
#  'Anicat',
#  'mataji ki nadi',
#  'Enicat',
#  'FOOD GRAIN',
#  '112908175457',
#  'DALI/JAGDISH KHATIK SC KUA',
#  'दोलपुरा नाडी गहरी करना गांव की बीच वाली नाडी सरदार जी का खेडा',
#  'एमजेएसए-दितिय फेज के तहत नाडी नवीनीकरण कार्य राजेन्\u200dद्र सागर (2724003312/WH/112908154721)',
#  'CHARAGA ME NADI NIRMAN RANIKHEDA',
#  'nimboliya nadhi gahri karna',
#  'uyuyuyuyuyuiiii',
#  '2724006262/WC/18/20102724006262/WC/18/2010',
#  'राजगढ एमजेएसए द्वितीय फेज के तहत नाडी रिनोवेशन कार्य स्\u200dकूल के पास गोठडा',
#  'उण्\u200dडी बालिया में चारागाह में नाडी गहरी करना पक्\u200dका कार्य',
#  'kasiyakhara',
#  'wh/16-17',
#  'BAMNIYA BAGRU MATA',
#  'kirtpura',
#  'ddsgdfhdfhjdfjhdfjdfj',
#  'खाखला ग्राम पंचायत भवन निर्माण कार्य खाखला',
#  'Ladu Bairwa',
#  'खाघान्\u200dन भण्\u200dडारण गोदान निर्माण कार्य मोहनपुरा',
#  'नाडी गहरी करना एंव पक्\u200dका कार्य',
#  'मोटरों का खेडा सतीमाता से जग्\u200dगा गुर्जर के खेत तक खाल ग\u200dहरा करना मोटरों का खेडा',
#  'सरथला खाघान भण्\u200dडारण गोदाम निर्माण कार्य सरथला',
#  'Renovation of Traditional Water Bodies',
#  'एमजेएस द्वितीय फेज के तहत नाडी गहरी कराना ओर वेस्\u200dटवियर कार्य',
#  'aqfrewertretre',
#  'बोराणा, कलालखेडी एनिकट निर्माण',
#  'भरक, माताजी का खेडा नाडी वेस्\u200dट वियर निर्माण व फेस',
#  'पनोि\u200dतया नाडी गहरी करना एंव पक्\u200dका कार्य',
#  'एमजेएसए-दितिय फेज के तहत नाडी नवीनीकरण कार्य चारागाह (2724003312/WH/112908154979)',
#  'wh/20909',
#  'WH/20794',
#  'एमजेएस दितीय फेज के तहत जागु बा के कुऐ के पास नाडी गहरीकरण कार्य',
#  'रेलाडी नाडी पर मिटटी कार्य व फेसवाल निर्माण कार्य पालडी',
#  '\tपालरा, मसाणिया एनिकट निर्माण, पचातरा का खेडा',
#  'PATELAI NADI PAR DANDA',
#  'एमजेएसए-दितिय फेज के तहत नई नाडी विस्\u200dतार कार्य (2724003312/WH/112908155266)',
#  'रूपानाथ जी के खेत के पास नाडी निर्माण कार्य',
#  'पोलाजी ऐनिकट पर फेसवाल व मिटी कार्य 16-17',
#  'CC Block',
#  '2724001034/WH/112908173136',
#  'BAGDI / HEERA BHIL',
#  'सुरास चारागाह मे जुना बीड की नाडी गहरी कराना मेहताजी का खेडा',
#  'खाद़य सुरक्षा गोदाम निर्माण कार्य -डाबला चान्\u200dदा',
#  'खाधान्\u200dन भण्\u200dडारण गोदाम निूर्माण कार्य सुरावास',
#  'scdsdfsfsdf',
#  ' 2724011001',
#  'complit work',
#  '112908144713',
#  'Joganoya Wali Naadi',
#  '112908133889',
#  'wh/51386',
#  'भारत निर्माण राजीव गान्धी सेवा केन्द्र रामपुरा म्\u200dबर 864014 के इन्\u200dदरा अावास निर्माण कार्य',
#  'WH/112908151677',
#  'Rural Connectivity',
#  '\t2724002081/FG/112908175543',
#  '\tकरणीपुरा स्\u200dकुल के पास एनिकट निर्माण कार्य करणीपुरा',
#  'होडा खाघान्\u200dन भण्\u200dडारण गोदाम निर्माण कार्य होडा',
#  '112908175921',
#  'एमजेएसए - द्वितीय फेज के तहत उदयसागर एनिकट गहरीकरण कार्य',
#  'WH/112908153155',
#  'दोलपुरा कल्\u200dला जी महाराज की नाडी गहरी करवाना एवं फसवाल निर्माण कार्य नाहरगढ/जोधपुरिया',
#  'Annicat',
#  'gadri khera',
#  'सार्व0 नाडी निर्माण कार्य सरेवडी',
#  'WH/17896',
#  '2724011208/FG/2701073662',
#  'एमजेएसए - द्वितीय फेज के तहत कालुसिंह के खेत के पास नाडी गहरीकरण कार्य',
#  'buildeng',
#  'soil sand ston',
#  'खादयान्न भण्\u200dडारण गोदाम निर्माण्\u200dा कार्य नान्\u200dदशा',
#  'नई नाडी निर्माण फेसवाल कार्य गुर्जरो का सेजा मोटरास',
#  'खाघान भण्\u200dडारण गोदाम निर्माण कार्य मोटरो का खेडा',
#  'सदारामजी का खेडा खाघान्\u200dन भंडारण केन्\u200dद्र सदारामजी का खेडा',
#  'Bagriya Nadi',
#  'sakrinadi',
#  '112774120746 ',
#  'Food Grain',
#  'renovation of water bodies',
#  'अनाज भण्\u200dडारण हेतु खाघान्\u200dन भण्\u200dडारण केन्\u200dद्र निर्माण कल्\u200dयाणपुरा',
#  'आगनवाडी भवन केन्\u200dद्र निर्माण कार्य आम्\u200dबाखेडा',
#  'khgfjkhgkgkjk',
#  'WH',
#  'चारागा\u200dह मे भू संरक्षण कार्य',
#  'माल का खेडा चरागाह मे नाडी निर्माण रपट कार्य',
#  'Katkadi nadi',
#  'Sugri Nadi Facewal',
#  'ENICUT',
#  'JAGDISH/SOHAN KHATIK SC KUA',
#  'चमारो का झोपडा में नाडी पिचिंग व सुरक्षा की दिवार',
#  'aav nirman',
#  'ramvir',
#  'एमजेएस द्वितीय फेज के तहत रामलाल गुर्जर के खेत के पास एनिकट गहरीकरण कार्य',
#  'Orther Work',
#  'चान्\u200dदजीकीखेडी खाध्\u200dयान्\u200dन भंडारण गोदाम निर्माण कार्य',
#  'नाडी निर्माण मानपुरा भोजपुरा',
#  'खाघान भण्\u200dडारण गोदाम निर्माण कार्य बीकरण',
#  'FG/72271',
#  'चरागाह विकास कार्य काबरा की डाग भोजपुरा',
#  'CHARAGHAH ME PURV NIRMIT NADI PAR FESWAL',
#  'kumhari nadi gahra',
#  'मकरेडी नाडी विस्\u200dतार व पानी आवक कार्य चारागाह केरखेडा',
#  'खाघान भण्\u200dडाारण गोदाम निर्माण कार्य थलकला',
#  'Water Harvesting',
#  'खाधान्\u200dन भण्\u200dडारण हेतु गोदाम निर्माण कार्य सोनियाणा',
#  'एमजेएसए दितीय फेज के तहत डूडी नाडी का गहरीकरण कार्य',
#  'खादयान्\u200dन भण्\u200dडारण गोदाम निर्माण कार्य खेमाणा',
#  'WH/112908151080',
#  'NATHOLAI ANICAT FESWAL',
#  'nadi pr mittti work',
#  'NAI NADI DHAMNIYA NARSARI FESWAL',
#  'Nayi Nadi Nirman',
#  'KUWADA NADI',
#  'थलकला एमजेएसए दितीय फेज के तहत रूपरेल नाडी गहरी करना',
#  'anganbari centre',
#  'satitya nada ghra krna v danda nirman',
#  'chatur sagar vijaypur pr miti kary',
#  'Mundeta me nade nirman',
#  'kalu/choga bhil',
#  'Renovation of Dharam Talai',
#  'नाडी गहरी करना अधुरे कार्य को पूर्ण करना बालापुरा',
#  'JASDHKJASHDKJSD',
#  'wh',
#  'Water conversation',
#  'एमजेएसए - द्वितीय फेज के तहत स्\u200dकुल के पास नाडी गहरीकरण कार्य',
#  'एमजेएसए - द्वितीय फेज के तहत ईट भटटे के पास नाडी गहरीकरण 2 कार्य',
#  'fg',
#  'Nadi Nirman',
#  'आव निर्माण पथवारी का नाडा रामपुरा',
#  'आगनबाडी केन्द्र भवन निमाॅण गांधीनगर',
#  'Nadi Gahri karna Amartiya ka jhopra',
#  'एमजेएस के तहत जोइडा बावजी चारागाह मे नाडी निर्माण कार्य टुगचख्\u200dेाडा',
#  '2724011209/WH/112908150188 ~~~~ चारागाह भुमि मे नायको की समेती के पास नाडी गहरी करना बिजोलिया कला',
#  'harnath gurjar ke makan se rameshawer mali ke makan tak',
#  'cc block',
#  '\tनई आबादी में भील बस्\u200dती खुर्रा निर्माण',
#  '\tमाना नाडी की फेसवाल व मीटी कार्य',
#  'खाद्यान भण्डारण गोदाम निर्माण कार्य - रुपाहेली',
#  'एमजेएसए द्वितीय फेज के तहत राठोडो की नाडी का गहरीकरण कार्य',
#  'एमजेएसए - द्वितीय फेज के तहत एनिकट का गहरिकरण कार्य',
#  'nadi faishwal',
#  'nadi nirman',
#  'एमजेएसए द्व\u200dितिय फेज के तहत चारागाह एनिकट गहरीकरण कार्य',
#  'Dhram Nadi',
#  'dharm nadi',
#  'NADI NIRMAN',
#  'खाद्य सुरक्षा गोदान निर्माण कार्य-सरेरी',
#  '7655',
#  'Aaganwadi nirman',
#  'anikat',
#  'renovation of trad. water bodies',
#  'op/73105',
#  'फैशवाल कार्य',
#  'कांगणी, टापरिया नाडी गहरी करवाना पिचिंग कार्य वेस्\u200dटवीयर निर्माण',
#  'नाडी गहरी करना एंव पक्\u200dका कार्य बकाण',
#  'sumshan',
#  'खादयान्\u200dन भण्\u200dडारण गोदाम निर्माण कार्य थला',
#  '\tधर्मीनाडी गहरी एवं फेसवाल निर्माण गांव के नीचे धर्मीनाडी जयसिंहपुरा परा',
#  'complate work',
#  'RAKSHI MEENO K ANICAT FESWAL',
#  'Fedar Nerman',
#  'RAMDEV JI KE STHAN PAR RAMSAGAR NADI PAR FESWAL',
#  'मामा देव फीडर आव की मरम्\u200dमत कार्य',
#  'wh/119665',
#  'नाथडियास  नाडी गहरी करना व पक्\u200dका काय्र',
#  '2724011210/FG/112908144663',
#  'Mathura lal',
#  'एमजेएसए - द्वितीय फेज के तहत चारागाह में छोटा एनिकट गहरिकरण कार्य',
#  'राजगढ एमजेएसए दितीय फेज के तहत लक्ष्\u200dमीपुरा नाडी गहरी करना व मरम्\u200dमतकार्यदेवनारायणकेपास लक्ष्\u200dमीपुरा',
#  'c.c balok dhakad mohla',
#  'Kheda Hetam Jhopada ciment block Kharnja',
#  'छोकावतो के एनिकट पर मिटटी कार्य लाछुडा',
#  'बोराणा, भीलों का खेडा एनिकट निर्माण',
#  'WH/49889',
#  'food gain',
#  'rural connectivity',
#  '2724011222/FG/112908175453',
#  'गोवटा बाधॅ के माइनर धोरो की सफाई बीड का खेडा   Work Start Date',
#  'बोराणा, चरावन माता जी के मंगरे में एनिकट निर्माण',
#  'एमजेएसए-दितिय फेज के तहत नाडी नवीनीकरण कार्य जीएसएस के पीछे (2724003312/WH/112908154980)',
#  'Charagah Me nai Nadi',
#  'WH/112908154646',
#  'धर्मी नाडी पर फेसवाल व मिटी कार्य बडला',
#  'Earth Work',
#  '112908175461',
#  'mohan mali ke makan se ramkishan gurjar ke makan tak cc',
#  '2724011221/FG/112908175447',
#  'एमजेएसए - द्वितीय फेज के तहत ईट भटटे के पास नाडी गहरीकरण 1 कार्य',
#  'एमजेएसए -द्व\u200dितिय फेज के तहत केपिसिटी एमिनमेंट ऑफ भैरूजी के चारागाह मे',
#  'नाडी बहरी करना पूलिया के पास महुवा',
#  'सरथला एमजेएसए दितीय फेज के तहत एनिकट मरम्\u200dमत कार्य देवनारायण के पास लटाला',
#  'परडोदास मेर बावजी के स्थान से चारागाह भूमि धर्मिनाडी व् फेशवाल कार्य   ',
#  'WATER HARVESTING',
#  'WH/112908167817',
#  'भीलो की नाडी फेसवाल रपट कार्य बहादुरपुरा पालडी',
#  'एमजेएस िदतीय फेज के तहत भवाना बलाई के खेत के पास एनिकट गहरीकरण कार्य',
#  'खाधान्\u200dन भण्\u200dडारण गोदाम निूर्माण कार्य माझावास',
#  '2724004065/WH/112908150533',
#  'Water Conservation',
#  'KABIRSTHAN BAWNDRI',
#  'चारागाह विकास कार्य',
#  'चावंडिया सीता सागर विस्\u200dतार व फेसवाल व रपट निर्माण कार्य ठेकला',
#  'panni ki aaw nirman',
#  'mardiya nada',
#  '\t2724002090/FG/112908175534',
#  'भारत निर्माण राजीव गांधी सेवा केन्\u200dद्र संग्रामगढ',
#  'wh/50427',
#  'Nadi',
#  'fjhkjgkjhlkhlhk',
#  '0123456789',
#  'jhaliya nadi ko ghra karna',
#  'खाद्यान्न भंडारण',
#  'Amra Nada Gahra Karana',
#  'Charagah me nadi',
#  'बागरिया नाड़ा गहरा करना',
#  '112908144658',
#  'chapri anyket',
#  'किशनपुरा बनी से बेडच नदी तक पाडोली खाल को धामनगटी',
#  'मोहनपुरा पुरानी नाडी की मरम्\u200dमत करवाना एनिकट कि उपर स्\u200dवरूपपुरा',
#  'खटवाडा उरीया नाडी को गहरा करना व मरम्\u200dमत कार्य राणीखेडा',
#  'पालरा,चैकडेम निर्माण, भीलों का खेडा',
#  'Charagah me Nadi Nirman Barliyas',
#  'बरून्\u200dदनी खाघान्\u200dन भण्\u200dडार केन्\u200dद्र निर्माण बरून्\u200dदनी',
#  'Soil Work',
#  'GITTI KI KHAN NADI',
#  'GORDHAN/ MANGU CHAMAR',
#  'chothmal / hariya kanjar',
#  'bhilo k kheto k anicat',
#  '~~~~ एमजेएस के तहत सार्व0 नाडा गहरा करना व फसवाल कार्य ठीकरिया',
#  'wc',
#  'नाडी गहरी कराना रामडुंगरी के पास महुवा',
#  'tretrtrtrtr',
#  '2724011207/FG/2701072449',
#  '2724001031/WH/112908153626 भगवानपुरा मे धर्मी नाड़ी आव निर्माण',
#  'khatoli nadi gahri krna',
#  'दितिय फेज के तहत नाडी रिपेयर भील बस्\u200dती के पास रलायता',
#  'सुरास चारागाह मे नाडी गहरी कराना देवनारायण के पास सुरास',
#  'धर्मी नाडी पर मिटटी कार्य व सरी बन्\u200dधाई कार्य',
#  'खाघान भण्\u200dडारण गोदाम निर्माण कार्य लाडपुरा',
#  'DEV JI KI NADI PR CHADAR NIRMAN V MITI KARY',
#  'ganesh jonval',
#  'नानु / लुम्बा भील जेविक बाड मय मेडबन्दी कार्य',
#  'Dharmau nadi',
#  'एमजेएसए-दितिय फेज के तहत नाडी नवीनीकरण कार्य व देवरे के पास चादर निर्माण',
#  'Earth Work On Nadi',
#  'थोरिया भ्रुना को गहरा व फेसवालनिर्माण कार्य भैरूखेडा',
#  'Geraval shadak',
#  'मकरेडी नाडी विस्\u200dतार व पानी आवक कार्य चारागाह आट',
#  'BariDand Nadi',
#  'WH/112908150616',
#  'बोरिया थाक नाडी की फेसवाल र्निमाण करना',
#  'mjsa 2 fej',
#  'आशाहोली पेयजल कुए के पास डबलु एच एस निर्माण',
#  'खाधान्\u200dन भण्\u200dडारण गोदाम निूर्माण कार्य अरनिया',
#  'S T Mohalla Se Bhimdawas raste par cc black',
#  'नाडी गहरी करना शंकर सिंह जी के कुएं के पास महुवा',
#  'food grain',
#  '2701072717',
#  'akberpura me dang vali nadi ko ghra krna',
#  '112908153293',
#  'सुकालिया मे नाडी निर्माण कार्य',
#  'Water Harversation',
#  'एमजेएसए - द्रितीय फेज के तहत नाडी रिनोवेशन',
#  'gfdgfdgfgfgfgfdsg',
#  'धोरा की नाडी गहरी व फेसवाल निमार्ण कार्य',
#  '7652',
#  'upandra kumar',
#  'खाघान भण्\u200dडारण गोदाम निर्माण कार्य सिंगोली',
#  '2724004051/WH/112774117816',
#  'एमजेएसए द्व\u200dितिय फेज के तहत बनजारा बस्\u200dती के पिछे नाडी का गहरीकरण कार्य',
#  'gramme panchyat work',
#  'balaiyo ki nadi ghrhi krna mori nirman',
#  'kad gogam',
#  'Kailash Nadi',
#  'sarv nadi',
#  'गुजरी नाडी की मरम्\u200dमत कार्य',
#  '2724011256/FG/112908145742',
#  'enict',
#  'Individual Work',
#  'Dharm Nadi Nirman',
#  'faishwal nirman or gahra krna',
#  'Renovation of Water Bodies',
#  'dharma talai ko gaheri karvana aur pal karya',
#  'कालु नायक के मकान से लम्\u200dबरदार तक cc इन्\u200dटर परासोली',
#  '2724009138/FG/112908144386',
#  'WH/112908150141',
#  'खाद्यान भण्डारण गोदाम निर्माण कार्य - आगुचा',
#  'bandudi ki nadee',
#  'GAWAE NADI',
#  'bhairu gurjar ke makan se kailash gurjar makan tak',
#  '2724011244/FG/112908175503',
#  'podharopan 200',
#  'cc balok tejaji se pathvari tak',
#  'gjh',
#  'Annicute nirman',
#  'NANU BHL KE PAS ANIKAT PAR CHADAR',
#  'cat 4 work',
#  'बगतु गुर्जर के खेत के पास नाडी निर्माण कार्य',
#  '/AV/112908206859 ~~~~ मालका खेडा श्\u200dमसान घाट विकास कार्य धनवाडा',
#  'Water Harvesting ',
#  'WH/51387',
#  'बीडा का खेडा नाडी गहरी करना',
#  'Nadi Work',
#  'WH/49888']
